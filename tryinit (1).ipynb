# %%
import request
from bs4 import BeautifulSoup

# %%
#define our endpoint
endpoint = r"https://www.sec.gov/cgi-bin/browse-edgar"

#define our parameters
param_dict = {'action':'getcompany', 
              'CIK':'789019',
              'type':'10-k',
              'dateb':'20190101',
              'owner':'exclude',
              'start':'',
              'output':'atom',
              'count':'100'}
#define our response
response = request.get(url=endpoint, params = param_dict)
response.content
